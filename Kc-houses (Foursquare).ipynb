# %%
import pandas as pd
import numpy as np

import requests
from pandas.io.json import json_normalize
import os

from geopy.geocoders import Nominatim

# %%
df_districts = pd.read_csv('kc_house_data.csv')

# %%
pd.set_option('display.max_columns', None)
df_districts.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1955             0    98178  47.5112 -122.257
# 1            400      1951          1991    98125  47.7210 -122.319
# 2              0      1933             0    98028  47.7379 -122.233
# 3            910      1965             0    98136  47.5208 -122.393
# 4              0      1987             0    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15     Region
# 0           1340        5650    Seattle
# 1           1690        7639    Seattle
# 2           2720        8062    Kenmore
# 3           1360        5000    Seattle
# 4           1800        7503  Sammamish

# %%
df_districts.Region.replace({'BlackDiamond':'Black Diamond'}, inplace=True)

# %%
df_districts = pd.DataFrame(df_districts.Region.unique())
df_districts.columns = ['Region']

# %% [markdown]
# **I am using Geopy to acquire the center of Regions (calculating just the average could have skewed them to one side because of some outlier points in regions):**

# %%
lat,lng = [],[]
for d in list(df_districts['Region'].unique()):
    address = d+', Washington'
    geolocator = Nominatim(user_agent='http')
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    lat.append(latitude)
    lng.append(longitude)

# %%
df_districts['Latitude'],df_districts['Longitude'] = lat,lng
df_districts
# Out:
#            Region   Latitude   Longitude
# 0         Seattle  47.603832 -122.330062
# 1         Kenmore  47.757320 -122.244015
# 2       Sammamish  47.608844 -122.042307
# 3         Redmond  47.669414 -122.123877
# 4     Federal Way  47.313494 -122.339310
# 5    Maple Valley  47.366423 -122.043713
# 6        Bellevue  47.614422 -122.192337
# 7          Duvall  47.742322 -121.985678
# 8          Auburn  47.307537 -122.230181
# 9   Mercer Island  47.560207 -122.220142
# 10           Kent  47.382690 -122.227027
# 11       Issaquah  47.534878 -122.043297
# 12         Renton  47.479908 -122.203450
# 13         Vashon  47.448050 -122.460670
# 14       Kirkland  47.685957 -122.192025
# 15  Black Diamond  47.308308 -122.003758
# 16     North Bend  47.495946 -121.785154
# 17    Woodinville  47.754583 -122.158890
# 18     Snoqualmie  47.528953 -121.827093
# 19       Enumclaw  47.204779 -121.991637
# 20      Fall City  47.566138 -121.888614
# 21        Bothell  47.759870 -122.206829
# 22      Carnation  47.647513 -121.912942
# 23         Medina  47.620548 -122.226445

# %% [markdown]
# **Foursquare API**

# %%
CLIENT_ID = '...' 
CLIENT_SECRET = '...'  
VERSION = '20180605'

# %% [markdown]
# First I am going to focus on one district to show the mechanism. Then I will create a loop and find venues for all the 24 districts.

# %%
lat_lng = df_districts[df_districts['Region']=='Seattle'].loc[:,['Latitude','Longitude']]
lat = lat_lng.iloc[:,0].reset_index(drop=True)[0]
lng = lat_lng.iloc[:,1].reset_index(drop=True)[0]
print(lat, lng)
# Out:
# 47.6038321 -122.3300624

# %%
radius = 10000
limit = 200

url_seattle = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, lat, lng, VERSION, radius, limit)

results = requests.get(url_seattle).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f2a894da0f35c7b88f1b347'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'},
#     {'name': '$-$$$$', 'key': 'price'}]},
#   'headerLocation': 'Seattle',
#   'headerFullLocation': 'Seattle',
#   'headerLocationGranularity': 'city',
#   'totalResults': 242,
#   'suggestedBounds': {'ne': {'lat': 47.69383219000009,
#     'lng': -122.1968304380397},
#    'sw': {'lat': 47.51383200999991, 'lng': -122.46329436196031}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '451c049bf964a520803a1fe3',
#        'name': 'Columbia Tower Club',
#        'location': {'address': '701 5th Ave Fl 75',
#         'lat': 47.60450651693834,
#         'lng': -122.33048379421234,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.60450651693834,
#           'lng': -122.33048379421234},
#          {'label': 'entrance', 'lat': 47.604432, 'lng': -122.330763}],
#         'distance': 81,
#         'postalCode': '98104',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['701 5th Ave Fl 75',
#          'Seattle, WA 98104',
#          'United States']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a33',
#          'name': 'Social Club',
#          'pluralName': 'Social Clubs',
#          'shortName': 'Social Club',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-451c049bf964a520803a1fe3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5762cc9ccd1085a720b1433e',
#        'name': 'Biscuit B*tch',
#        'location': {'address': '621 3rd Ave',
#         'crossStreet': 'James St & Cherry St',
#         'lat': 47.603237,
#         'lng': -122.33201,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.603237,
#           'lng': -122.33201}],
#         'distance': 160,
#         'postalCode': '98104',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['621 3rd Ave (James St & Cherry St)',
#          'Seattle, WA 98104',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'shortName': 'Breakfast',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5762cc9ccd1085a720b1433e-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '455c500ef964a5206e3d1fe3',
#        'name': "Tat's Delicatessen",
#        'location': {'address': '159 Yesler Way',
#         'crossStreet': 'at 2nd Ave',
#         'lat': 47.601901016106545,
#         'lng': -122.3324232258795,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.601901016106545,
#           'lng': -122.3324232258795},
#          {'label': 'entrance', 'lat': 47.60163, 'lng': -122.332364}],
#         'distance': 278,
#         'postalCode': '98104',
#         'cc': 'US',
#         'neighborhood': 'Pioneer Square',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['159 Yesler Way (at 2nd Ave)',
#          'Seattle, WA 98104',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-455c500ef964a5206e3d1fe3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a3be500f964a520e2a01fe3',
#        'name': 'Tsukushinbo',
#        'location': {'address': '515 S Main St',
#         'crossStreet': 'btw 5th & 6th Ave S',
#         'lat': 47.59996315315612,
#         'lng': -122.32687778842212,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.59996315315612,
#           'lng': -122.32687778842212},
#          {'label': 'entrance', 'lat': 47.59994, 'lng': -122.326864}],
#         'distance': 492,
#         'postalCode': '98104',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['515 S Main St (btw 5th & 6th Ave S)',
#          'Seattle, WA 98104',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2031600',
#         'url': 'https://www.grubhub.com/restaurant/tsukushinbo-restaurant-515-s-main-st-seattle/2031600?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2031600',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a3be500f964a520e2a01fe3-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '41f98080f964a5203b1f1fe3',
#        'name': 'Benaroya Hall',
#        'location': {'address': '200 University St',
#         'crossStreet': 'btwn 2nd & 3rd Ave',
#         'lat': 47.60795746772859,
#         'lng': -122.33645572511435,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.60795746772859,
#           'lng': -122.33645572511435}],
#         'distance': 664,
#         'postalCode': '98101',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['200 University St (btwn 2nd & 3rd Ave)',
#          'Seattle, WA 98101',
#          'United States']},
#        'categories': [{'id': '5032792091d4c4b30a586d5c',
#          'name': 'Concert Hall',
#          'pluralName': 'Concert Halls',
#          'shortName': 'Concert Hall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-41f98080f964a5203b1f1fe3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0c7f0bf964a5204f3e23e3',
#        'name': 'Four Seasons Seattle',
#        'location': {'address': '99 Union St',
#         'crossStreet': 'at 1st Ave',
#         'lat': 47.607469754725216,
#         'lng': -122.33936884144804,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.607469754725216,
#           'lng': -122.33936884144804},
#          {'label': 'entrance', 'lat': 47.607638, 'lng': -122.339307}],
#         'distance': 807,
#         'postalCode': '98101',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['99 Union St (at 1st Ave)',
#          'Seattle, WA 98101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b0c7f0bf964a5204f3e23e3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '47efbb37f964a5206f4e1fe3',
#        'name': 'Kinokuniya Book Store',
#        'location': {'address': '525 S Weller St',
#         'crossStreet': 'at 6th Ave S',
#         'lat': 47.59730729413182,
#         'lng': -122.32677280990137,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.59730729413182,
#           'lng': -122.32677280990137},
#          {'label': 'entrance', 'lat': 47.597414, 'lng': -122.326646}],
#         'distance': 767,
#         'postalCode': '98104',
#         'cc': 'US',
#         'neighborhood': 'International District',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['525 S Weller St (at 6th Ave S)',
#          'Seattle, WA 98104',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-47efbb37f964a5206f4e1fe3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51d9cb4d498e71691005418d',
#        'name': 'Ellenos Real Greek Yogurt',
#        'location': {'address': '1500 Pike St, #12',
#         'crossStreet': 'Pike Place & Pike Street',
#         'lat': 47.60884772199345,
#         'lng': -122.34047600660855,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.60884772199345,
#           'lng': -122.34047600660855}],
#         'distance': 960,
#         'postalCode': '98101',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['1500 Pike St, #12 (Pike Place & Pike Street)',
#          'Seattle, WA 98101',
#          'United States']},
#        'categories': [{'id': '512e7cae91d4cbb4e5efe0af',
#          'name': 'Frozen Yogurt Shop',
#          'pluralName': 'Frozen Yogurt Shops',
#          'shortName': 'Yogurt',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/frozenyogurt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51d9cb4d498e71691005418d-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aa42487f964a520834520e3',
#        'name': "Fran's Chocolates",
#        'location': {'address': '1325 1st Ave',
#         'crossStreet': 'at Union St',
#         'lat': 47.607680997438955,
#         'lng': -122.33930423218398,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.607680997438955,
#           'lng': -122.33930423218398},
#          {'label': 'entrance', 'lat': 47.607519, 'lng': -122.339023}],
#         'distance': 815,
#         'postalCode': '98101',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['1325 1st Ave (at Union St)',
#          'Seattle, WA 98101',
#          'United States']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b31',
#          'name': 'Chocolate Shop',
#          'pluralName': 'Chocolate Shops',
#          'shortName': 'Chocolate Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/candystore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1550230',
#         'url': 'https://www.grubhub.com/restaurant/frans-1325-1st-avenue-seattle/1550230?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1550230',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4aa42487f964a520834520e3-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf960cb4a67c928f2b826cf',
#        'name': 'Pike Place Fish Market',
#        'location': {'address': '86 Pike Pl',
#         'lat': 47.60881291103749,
#         'lng': -122.34037068853783,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.60881291103749,
#           'lng': -122.34037068853783}],
#         'distance': 951,
#         'postalCode': '98101',
#         'cc': 'US',
#         'neighborhood': 'Pike Place',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['86 Pike Pl',
#          'Seattle, WA 98101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10e951735',
#          'name': 'Fish Market',
#          'pluralName': 'Fish Markets',
#          'shortName': 'Fish Market',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_fishmarket_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf960cb4a67c928f2b826cf-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '427ea800f964a520b1211fe3',
#        'name': 'Pike Place Market',
#        'location': {'address': '85 Pike St',
#         'crossStreet': 'at Pine St',
#         'lat': 47.60919539828014,
#         'lng': -122.34125829789713,
#         'distance': 1030,
#         'postalCode': '98101',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['85 Pike St (at Pine St)',
#          'Seattle, WA 98101',
#          'United States']},
#        'categories': [{'id': '50be8ee891d4fa8dcc7199a7',
#          'name': 'Market',
#          'pluralName': 'Markets',
#          'shortName': 'Market',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/market_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2114377',
#         'url': 'https://www.grubhub.com/restaurant/el-borracho-pike-place-market-1521-1st-ave-seattle/2114377?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2114377',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-427ea800f964a520b1211fe3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '44c14900f964a520b8351fe3',
#        'name': 'Uwajimaya',
#        'location': {'address': '600 5th Ave S',
#         'crossStreet': 'at S Dearborn St',
#         'lat': 47.59685532,
#         'lng': -122.32686411,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.59685532,
#           'lng': -122.32686411}],
#         'distance': 812,
#         'postalCode': '98104',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['600 5th Ave S (at S Dearborn St)',
#          'Seattle, WA 98104',
#          'United States']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1581114',
#         'url': 'https://www.grubhub.com/restaurant/uwajimaya-village-food-court-600-5th-avenue-south-seattle/1581114?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1581114',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-44c14900f964a520b8351fe3-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b295179f964a520d49c24e3',
#        'name': 'MarketSpice',
#        'location': {'address': '85 A Pike Pl',
#         'crossStreet': 'at Pike St & Pike Pl',
#         'lat': 47.608580115021844,
#         'lng': -122.34040722618163,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.608580115021844,
#           'lng': -122.34040722618163}],
#         'distance': 939,
#         'postalCode': '98101',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['85 A Pike Pl (at Pike St & Pike Pl)',
#          'Seattle, WA 98101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1f5941735',
#          'name': 'Gourmet Shop',
#          'pluralName': 'Gourmet Shops',
#          'shortName': 'Gourmet',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b295179f964a520d49c24e3-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4abd05d0f964a5201c8820e3',
#        'name': 'World Spice Merchants',
#        'location': {'address': '1509 Western Ave',
#         'lat': 47.608622,
#         'lng': -122.34155,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.608622,
#           'lng': -122.34155},
#          {'label': 'entrance', 'lat': 47.608617, 'lng': -122.341522}],
#         'distance': 1013,
#         'postalCode': '98101',
#         'cc': 'US',
#         'neighborhood': 'Pike Place',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['1509 Western Ave',
#          'Seattle, WA 98101',
#          'United States']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b2c',
#          'name': 'Herbs & Spices Store',
#          'pluralName': 'Herbs & Spices Stores',
#          'shortName': 'Herbs & Spices Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4abd05d0f964a5201c8820e3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '43768200f964a5204d2a1fe3',
#        'name': 'CenturyLink Field',
#        'location': {'address': '800 Occidental Ave S',
#         'lat': 47.59478900349768,
#         'lng': -122.33190396637805,
#         'distance': 1016,
#         'postalCode': '98134',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['800 Occidental Ave S',
#          'Seattle, WA 98134',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d184941735',
#          'name': 'Stadium',
#          'pluralName': 'Stadiums',
#          'shortName': 'Stadium',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '34240331'}},
#       'referralId': 'e-0-43768200f964a5204d2a1fe3-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '42a63500f964a5200a251fe3',
#        'name': 'Seattle Art Museum',
#        'location': {'address': '1300 1st Ave',
#         'crossStreet': 'btwn Union & University',
#         'lat': 47.60705223081685,
#         'lng': -122.33781915742607,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.60705223081685,
#           'lng': -122.33781915742607}],
#         'distance': 683,
#         'postalCode': '98101',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['1300 1st Ave (btwn Union & University)',
#          'Seattle, WA 98101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d18f941735',
#          'name': 'Art Museum',
#          'pluralName': 'Art Museums',
#          'shortName': 'Art Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_art_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-42a63500f964a5200a251fe3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a41576ff964a52027a51fe3',
#        'name': "Beecher's Handmade Cheese",
#        'location': {'address': '1600 Pike Pl',
#         'crossStreet': 'at Pine St',
#         'lat': 47.60956997146841,
#         'lng': -122.34185099601746,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.60956997146841,
#           'lng': -122.34185099601746},
#          {'label': 'entrance', 'lat': 47.609687, 'lng': -122.341919}],
#         'distance': 1091,
#         'postalCode': '98101',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['1600 Pike Pl (at Pine St)',
#          'Seattle, WA 98101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d11e951735',
#          'name': 'Cheese Shop',
#          'pluralName': 'Cheese Shops',
#          'shortName': 'Cheese Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_cheese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2199224',
#         'url': 'https://www.grubhub.com/restaurant/beechers-handmade-cheese-1600-pike-pl-seattle/2199224?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2199224',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '95370685'}},
#       'referralId': 'e-0-4a41576ff964a52027a51fe3-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c8ae4ef9ef0224b5c775f7b',
#        'name': 'Seattle Waterfront',
#        'location': {'address': '2711-2799 Alaskan Way',
#         'lat': 47.60639398655344,
#         'lng': -122.34112966639444,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.60639398655344,
#           'lng': -122.34112966639444}],
#         'distance': 878,
#         'postalCode': '98121',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['2711-2799 Alaskan Way',
#          'Seattle, WA 98121',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d5734c3',
#          'name': 'Waterfront',
#          'pluralName': 'Waterfronts',
#          'shortName': 'Waterfront',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/river_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c8ae4ef9ef0224b5c775f7b-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51c1286f498e2505fd764fbe',
#        'name': "Rachel's Ginger Beer",
#        'location': {'address': '1530 Post Aly',
#         'lat': 47.609648331726504,
#         'lng': -122.34142532549396,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.609648331726504,
#           'lng': -122.34142532549396}],
#         'distance': 1070,
#         'postalCode': '98101',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['1530 Post Aly',
#          'Seattle, WA 98101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'shortName': 'Cocktail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51c1286f498e2505fd764fbe-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52251f9511d2b2f238901956',
#        'name': 'Storyville Coffee Company',
#        'location': {'address': '94 Pike St #34',
#         'crossStreet': '1st Ave (Pike Place Market)',
#         'lat': 47.608968412285684,
#         'lng': -122.34069716145795,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.608968412285684,
#           'lng': -122.34069716145795}],
#         'distance': 981,
#         'postalCode': '98101',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['94 Pike St #34 (1st Ave (Pike Place Market))',
#          'Seattle, WA 98101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52251f9511d2b2f238901956-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '439169aaf964a5205a2b1fe3',
#        'name': 'Elliott Bay Book Company',
#        'location': {'address': '1521 10th Ave',
#         'crossStreet': 'btwn Pike & Pine',
#         'lat': 47.614689085848305,
#         'lng': -122.31988535732319,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.614689085848305,
#           'lng': -122.31988535732319}],
#         'distance': 1429,
#         'postalCode': '98122',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['1521 10th Ave (btwn Pike & Pine)',
#          'Seattle, WA 98122',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-439169aaf964a5205a2b1fe3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '563ede7bcd10f3a329203068',
#        'name': 'JarrBar',
#        'location': {'address': '1432 Western Ave',
#         'lat': 47.608291649883355,
#         'lng': -122.3410413650964,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.608291649883355,
#           'lng': -122.3410413650964},
#          {'label': 'entrance', 'lat': 47.608275, 'lng': -122.340889}],
#         'distance': 961,
#         'postalCode': '98101',
#         'cc': 'US',
#         'neighborhood': 'Pike Place',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['1432 Western Ave',
#          'Seattle, WA 98101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1554931',
#         'url': 'https://www.grubhub.com/restaurant/jarrbar-1432-western-avenue-seattle/1554931?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1554931',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-563ede7bcd10f3a329203068-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5986b87f16ef6778abe2c885',
#        'name': 'Salt & Straw',
#        'location': {'address': '714 E Pike St Ste A',
#         'lat': 47.61415770404166,
#         'lng': -122.3233996275977,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.61415770404166,
#           'lng': -122.3233996275977}],
#         'distance': 1253,
#         'postalCode': '98122',
#         'cc': 'US',
#         'neighborhood': 'Capitol Hill',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['714 E Pike St Ste A',
#          'Seattle, WA 98122',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5986b87f16ef6778abe2c885-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b205a92364d97002c14a5fb',
#        'name': 'Victrola Coffee Roasters',
#        'location': {'address': '1600 3rd Ave',
#         'crossStreet': 'Pine St',
#         'lat': 47.610894693944324,
#         'lng': -122.33895175552335,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.610894693944324,
#           'lng': -122.33895175552335},
#          {'label': 'entrance', 'lat': 47.611178, 'lng': -122.338886}],
#         'distance': 1031,
#         'postalCode': '98101',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['1600 3rd Ave (Pine St)',
#          'Seattle, WA 98101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b205a92364d97002c14a5fb-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56380a1ecd10193ef6e851ce',
#        'name': 'General Porpoise Coffee & Doughnuts',
#        'location': {'address': '1060 E Union St',
#         'crossStreet': '11th Ave',
#         'lat': 47.613048369367704,
#         'lng': -122.31877882545173,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.613048369367704,
#           'lng': -122.31877882545173},
#          {'label': 'entrance', 'lat': 47.613031, 'lng': -122.318519}],
#         'distance': 1330,
#         'postalCode': '98122',
#         'cc': 'US',
#         'neighborhood': 'Capitol Hill',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['1060 E Union St (11th Ave)',
#          'Seattle, WA 98122',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d148941735',
#          'name': 'Donut Shop',
#          'pluralName': 'Donut Shops',
#          'shortName': 'Donuts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56380a1ecd10193ef6e851ce-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c3b7509be4620a1f1630c13',
#        'name': 'Homegrown',
#        'location': {'address': '1531 Melrose Ave',
#         'lat': 47.61475082601138,
#         'lng': -122.32811456169942,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.61475082601138,
#           'lng': -122.32811456169942}],
#         'distance': 1224,
#         'postalCode': '98122',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['1531 Melrose Ave',
#          'Seattle, WA 98122',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c3b7509be4620a1f1630c13-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '42daf100f964a5202f261fe3',
#        'name': 'Tamarind Tree',
#        'location': {'address': '1036 S Jackson St',
#         'crossStreet': 'at 12th Ave S',
#         'lat': 47.59982899733872,
#         'lng': -122.31789066445099,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.59982899733872,
#           'lng': -122.31789066445099},
#          {'label': 'entrance', 'lat': 47.599315, 'lng': -122.31826}],
#         'distance': 1016,
#         'postalCode': '98104',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['1036 S Jackson St (at 12th Ave S)',
#          'Seattle, WA 98104',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14a941735',
#          'name': 'Vietnamese Restaurant',
#          'pluralName': 'Vietnamese Restaurants',
#          'shortName': 'Vietnamese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1554165',
#         'url': 'https://www.grubhub.com/restaurant/tamarind-tree-1036-south-jackson-street-seattle/1554165?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1554165',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-42daf100f964a5202f261fe3-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59ac98fb86bc494d390a32d5',
#        'name': 'Pho Bac Sup Shop',
#        'location': {'address': '1240 S Jackson St',
#         'lat': 47.59944334159577,
#         'lng': -122.31529782031112,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.59944334159577,
#           'lng': -122.31529782031112}],
#         'distance': 1211,
#         'postalCode': '98144',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['1240 S Jackson St',
#          'Seattle, WA 98144',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14a941735',
#          'name': 'Vietnamese Restaurant',
#          'pluralName': 'Vietnamese Restaurants',
#          'shortName': 'Vietnamese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59ac98fb86bc494d390a32d5-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dbdc9c36a23e294ba4e3ee8',
#        'name': 'Ba Bar',
#        'location': {'address': '550 12th Ave',
#         'crossStreet': 'at E Barclay St',
#         'lat': 47.60714856912167,
#         'lng': -122.31657821247472,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.60714856912167,
#           'lng': -122.31657821247472},
#          {'label': 'entrance', 'lat': 47.606973, 'lng': -122.316621}],
#         'distance': 1077,
#         'postalCode': '98122',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['550 12th Ave (at E Barclay St)',
#          'Seattle, WA 98122',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14a941735',
#          'name': 'Vietnamese Restaurant',
#          'pluralName': 'Vietnamese Restaurants',
#          'shortName': 'Vietnamese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dbdc9c36a23e294ba4e3ee8-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a823b1cf964a520f4f81fe3',
#        'name': 'Urban Yoga Spa',
#        'location': {'address': '1900 4th Ave',
#         'crossStreet': 'at Stewart St',
#         'lat': 47.6125202562606,
#         'lng': -122.33867036193942,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.6125202562606,
#           'lng': -122.33867036193942}],
#         'distance': 1163,
#         'postalCode': '98101',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['1900 4th Ave (at Stewart St)',
#          'Seattle, WA 98101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a823b1cf964a520f4f81fe3-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4276bf00f964a52083211fe3',
#        'name': 'Cinerama',
#        'location': {'address': '2100 4th Ave',
#         'crossStreet': 'at Lenora St',
#         'lat': 47.6142,
#         'lng': -122.34135,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.6142,
#           'lng': -122.34135},
#          {'label': 'entrance', 'lat': 47.614091, 'lng': -122.341494}],
#         'distance': 1431,
#         'postalCode': '98121',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['2100 4th Ave (at Lenora St)',
#          'Seattle, WA 98121',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d17f941735',
#          'name': 'Movie Theater',
#          'pluralName': 'Movie Theaters',
#          'shortName': 'Movie Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4276bf00f964a52083211fe3-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56b0e95c498e4f4c9f4cdb7b',
#        'name': 'Thompson Seattle',
#        'location': {'address': '110 Stewart St',
#         'lat': 47.6103545,
#         'lng': -122.3412645,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.6103545,
#           'lng': -122.3412645}],
#         'distance': 1110,
#         'postalCode': '98101',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['110 Stewart St',
#          'Seattle, WA 98101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '168706149'}},
#       'referralId': 'e-0-56b0e95c498e4f4c9f4cdb7b-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58269ec43398744fe420ea0e',
#        'name': "L'Oursin",
#        'location': {'address': '1315 E Jefferson St',
#         'lat': 47.60616043653752,
#         'lng': -122.31472055101055,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.60616043653752,
#           'lng': -122.31472055101055}],
#         'distance': 1180,
#         'postalCode': '98122',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['1315 E Jefferson St',
#          'Seattle, WA 98122',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1811802',
#         'url': 'https://www.grubhub.com/restaurant/loursin-1315-east-jefferson-street-seattle/1811802?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1811802',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58269ec43398744fe420ea0e-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e18cb79d1648b834836786e',
#        'name': 'Canon',
#        'location': {'address': '928 12th Ave',
#         'crossStreet': 'btwn E Spring & Marion St',
#         'lat': 47.611252580301,
#         'lng': -122.3166638576684,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.611252580301,
#           'lng': -122.3166638576684}],
#         'distance': 1301,
#         'postalCode': '98122',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['928 12th Ave (btwn E Spring & Marion St)',
#          'Seattle, WA 98122',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'shortName': 'Cocktail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '40110749'}},
#       'referralId': 'e-0-4e18cb79d1648b834836786e-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '423b6b80f964a52039201fe3',
#        'name': 'Honeyhole',
#        'location': {'address': '703 E Pike St',
#         'crossStreet': 'at Boylston Ave',
#         'lat': 47.61404473105211,
#         'lng': -122.32319695290957,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.61404473105211,
#           'lng': -122.32319695290957},
#          {'label': 'entrance', 'lat': 47.613962, 'lng': -122.323149}],
#         'distance': 1248,
#         'postalCode': '98122',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['703 E Pike St (at Boylston Ave)',
#          'Seattle, WA 98122',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-423b6b80f964a52039201fe3-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
# ...
#         'country': 'United States',
#         'formattedAddress': ['325 5th Ave N (at Harrison St)',
#          'Seattle, WA 98109',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d181941735',
#          'name': 'Museum',
#          'pluralName': 'Museums',
#          'shortName': 'Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '52421072'}},
#       'referralId': 'e-0-43601880f964a5202d291fe3-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a56af14f964a520a2b51fe3',
#        'name': 'Cafe Selam',
#        'location': {'address': '2715 E Cherry St',
#         'crossStreet': 'at 27th',
#         'lat': 47.60786326046941,
#         'lng': -122.29730498390884,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.60786326046941,
#           'lng': -122.29730498390884},
#          {'label': 'entrance', 'lat': 47.607841, 'lng': -122.297037}],
#         'distance': 2499,
#         'postalCode': '98122',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['2715 E Cherry St (at 27th)',
#          'Seattle, WA 98122',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10a941735',
#          'name': 'Ethiopian Restaurant',
#          'pluralName': 'Ethiopian Restaurants',
#          'shortName': 'Ethiopian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ethiopian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1560856',
#         'url': 'https://www.grubhub.com/restaurant/cafe-selam-2715-e-cherry-st-seattle/1560856?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1560856',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a56af14f964a520a2b51fe3-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fb449d4e4b0186ba35fff7c',
#        'name': 'The Grinning Yogi',
#        'location': {'address': '345 15th Ave E',
#         'crossStreet': 'Harrison',
#         'lat': 47.621812,
#         'lng': -122.312947,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.621812,
#           'lng': -122.312947}],
#         'distance': 2378,
#         'postalCode': '98112',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['345 15th Ave E (Harrison)',
#          'Seattle, WA 98112',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fb449d4e4b0186ba35fff7c-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4700c686f964a520354b1fe3',
#        'name': 'Center for Wooden Boats',
#        'location': {'address': '1010 Valley St',
#         'lat': 47.627010412070995,
#         'lng': -122.33619243379673,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.627010412070995,
#           'lng': -122.33619243379673},
#          {'label': 'entrance', 'lat': 47.626878, 'lng': -122.336058}],
#         'distance': 2620,
#         'postalCode': '98109',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['1010 Valley St',
#          'Seattle, WA 98109',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d181941735',
#          'name': 'Museum',
#          'pluralName': 'Museums',
#          'shortName': 'Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4700c686f964a520354b1fe3-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4436d6a5f964a5200b321fe3',
#        'name': 'Top Pot Doughnuts',
#        'location': {'address': '609 Summit Ave E',
#         'crossStreet': 'btwn Mercer & Roy',
#         'lat': 47.62462984576327,
#         'lng': -122.32546961676249,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.62462984576327,
#           'lng': -122.32546961676249},
#          {'label': 'entrance', 'lat': 47.62462, 'lng': -122.325442}],
#         'distance': 2340,
#         'postalCode': '98102',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['609 Summit Ave E (btwn Mercer & Roy)',
#          'Seattle, WA 98102',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d148941735',
#          'name': 'Donut Shop',
#          'pluralName': 'Donut Shops',
#          'shortName': 'Donuts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4436d6a5f964a5200b321fe3-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '542b0848498e259fb7853267',
#        'name': "Uncle Ike's CD",
#        'location': {'address': '2310 East Union Street',
#         'crossStreet': 'at 23rd Ave.',
#         'lat': 47.6131353,
#         'lng': -122.3016857,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.6131353,
#           'lng': -122.3016857}],
#         'distance': 2368,
#         'postalCode': '98122',
#         'cc': 'US',
#         'neighborhood': 'Central Distr',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['2310 East Union Street (at 23rd Ave.)',
#          'Seattle, WA 98122',
#          'United States']},
#        'categories': [{'id': '52c71aaf3cf9994f4e043d17',
#          'name': 'Marijuana Dispensary',
#          'pluralName': 'Marijuana Dispensaries',
#          'shortName': 'Dispensary',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/dispensary_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '468892153'}},
#       'referralId': 'e-0-542b0848498e259fb7853267-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb3731c715eef3bf45286bb',
#        'name': 'Olympic Sculpture Park Pocket Beach',
#        'location': {'lat': 47.61709400264109,
#         'lng': -122.35804672123568,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.61709400264109,
#           'lng': -122.35804672123568}],
#         'distance': 2567,
#         'postalCode': '98121',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['Seattle, WA 98121', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e2941735',
#          'name': 'Beach',
#          'pluralName': 'Beaches',
#          'shortName': 'Beach',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/beach_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb3731c715eef3bf45286bb-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55903f39498efe76684bc489',
#        'name': 'Boat Street Kitchen',
#        'location': {'address': '3131 Western Ave',
#         'lat': 47.61842992424893,
#         'lng': -122.35743804865922,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.61842992424893,
#           'lng': -122.35743804865922}],
#         'distance': 2619,
#         'postalCode': '98121',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['3131 Western Ave',
#          'Seattle, WA 98121',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55903f39498efe76684bc489-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '444eabf8f964a52093321fe3',
#        'name': 'Myrtle Edwards Park',
#        'location': {'address': '3130 Alaskan Way W',
#         'lat': 47.6191188961201,
#         'lng': -122.35999927289357,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.6191188961201,
#           'lng': -122.35999927289357}],
#         'distance': 2818,
#         'postalCode': '98121',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['3130 Alaskan Way W',
#          'Seattle, WA 98121',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-444eabf8f964a52093321fe3-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a906148f964a520951720e3',
#        'name': 'International Fountain',
#        'location': {'address': '305 Harrison St',
#         'crossStreet': 'Seattle Center',
#         'lat': 47.622486065907275,
#         'lng': -122.35232071726352,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.622486065907275,
#           'lng': -122.35232071726352}],
#         'distance': 2664,
#         'postalCode': '98109',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['305 Harrison St (Seattle Center)',
#          'Seattle, WA 98109',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573547',
#          'name': 'Fountain',
#          'pluralName': 'Fountains',
#          'shortName': 'Fountain',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a906148f964a520951720e3-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be9c56d61aca59369f68200',
#        'name': 'Lake Union Park',
#        'location': {'address': '860 Terry Ave N',
#         'lat': 47.62668985910958,
#         'lng': -122.33750961057686,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.62668985910958,
#           'lng': -122.33750961057686}],
#         'distance': 2605,
#         'postalCode': '98109',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['860 Terry Ave N',
#          'Seattle, WA 98109',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '535957534'}},
#       'referralId': 'e-0-4be9c56d61aca59369f68200-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '44142dc1f964a520ec301fe3',
#        'name': 'Volunteer Park',
#        'location': {'address': '1247 15th Ave E',
#         'lat': 47.62912253358359,
#         'lng': -122.3162988143689,
#         'distance': 2998,
#         'postalCode': '98112',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['1247 15th Ave E',
#          'Seattle, WA 98112',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-44142dc1f964a520ec301fe3-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '570a7e93498eff5fb39f0cc2',
#        'name': 'La Marzocco Cafe',
#        'location': {'address': '472 1st Ave N',
#         'crossStreet': 'At KEXP',
#         'lat': 47.6227316073658,
#         'lng': -122.35532257285617,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 47.6227316073658,
#           'lng': -122.35532257285617}],
#         'distance': 2831,
#         'postalCode': '98109',
#         'cc': 'US',
#         'city': 'Seattle',
#         'state': 'WA',
#         'country': 'United States',
#         'formattedAddress': ['472 1st Ave N (At KEXP)',
#          'Seattle, WA 98109',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1548837',
#         'url': 'https://www.grubhub.com/restaurant/la-marzocco-cafe--showroom-472-1st-avenue-north-seattle/1548837?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1548837',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-570a7e93498eff5fb39f0cc2-99'}]}]}}

# %% [markdown]
# Function for extracting category from the json file:

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
venues_seattlle = json_normalize(venues)
venues_seattlle.head(2)
# Out:
#    reasons.count                                      reasons.items  \
# 0              0  [{'summary': 'This spot is popular', 'type': '...
# 1              0  [{'summary': 'This spot is popular', 'type': '...
#
#                        referralId  \
# 0  e-0-451c049bf964a520803a1fe3-0
# 1  e-0-5762cc9ccd1085a720b1433e-1
#
#                                     venue.categories venue.delivery.id  \
# 0  [{'id': '52e81612bcbc57f1066b7a33', 'name': 'S...               NaN
# 1  [{'id': '4bf58dd8d48988d143941735', 'name': 'B...               NaN
#
#   venue.delivery.provider.icon.name venue.delivery.provider.icon.prefix  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
#
#   venue.delivery.provider.icon.sizes venue.delivery.provider.name  \
# 0                                NaN                          NaN
# 1                                NaN                          NaN
#
#   venue.delivery.url                  venue.id venue.location.address  \
# 0                NaN  451c049bf964a520803a1fe3      701 5th Ave Fl 75
# 1                NaN  5762cc9ccd1085a720b1433e            621 3rd Ave
#
#   venue.location.cc venue.location.city venue.location.country  \
# 0                US             Seattle          United States
# 1                US             Seattle          United States
#
#   venue.location.crossStreet  venue.location.distance  \
# 0                        NaN                       81
# 1       James St & Cherry St                      160
#
#                      venue.location.formattedAddress  \
# 0  [701 5th Ave Fl 75, Seattle, WA 98104, United ...
# 1  [621 3rd Ave (James St & Cherry St), Seattle, ...
#
#                        venue.location.labeledLatLngs  venue.location.lat  \
# 0  [{'label': 'display', 'lat': 47.60450651693834...           47.604507
# 1  [{'label': 'display', 'lat': 47.603237, 'lng':...           47.603237
#
#    venue.location.lng venue.location.neighborhood venue.location.postalCode  \
# 0         -122.330484                         NaN                     98104
# 1         -122.332010                         NaN                     98104
#
#   venue.location.state           venue.name  venue.photos.count  \
# 0                   WA  Columbia Tower Club                   0
# 1                   WA        Biscuit B*tch                   0
#
#   venue.photos.groups venue.venuePage.id
# 0                  []                NaN
# 1                  []                NaN

# %%
columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
venues_seattlle = venues_seattlle.loc[:,columns]
venues_seattlle.head(2)
# Out:
#             venue.name                                   venue.categories  \
# 0  Columbia Tower Club  [{'id': '52e81612bcbc57f1066b7a33', 'name': 'S...
# 1        Biscuit B*tch  [{'id': '4bf58dd8d48988d143941735', 'name': 'B...
#
#    venue.location.lat  venue.location.lng
# 0           47.604507         -122.330484
# 1           47.603237         -122.332010

# %% [markdown]
# To simplify dataframe I will use the created above function and than change the names of the columns.

# %%
venues_seattlle['venue.categories'] = venues_seattlle.apply(get_category_type, axis=1)
venues_seattlle.columns = [col.split('.')[-1] for col in venues_seattlle.columns]
venues_seattlle.head(5)
# Out:
#                   name           categories        lat         lng
# 0  Columbia Tower Club          Social Club  47.604507 -122.330484
# 1        Biscuit B*tch       Breakfast Spot  47.603237 -122.332010
# 2   Tat's Delicatessen       Sandwich Place  47.601901 -122.332423
# 3          Tsukushinbo  Japanese Restaurant  47.599963 -122.326878
# 4   Metropolitan Grill           Steakhouse  47.604617 -122.334280

# %%
venues_seattlle.categories.value_counts()
# Out:
# Coffee Shop                      10
# Hotel                             7
# Bakery                            5
# Vietnamese Restaurant             5
# Seafood Restaurant                4
# Italian Restaurant                3
# Sandwich Place                    3
# Dumpling Restaurant               3
# Sushi Restaurant                  3
# Deli / Bodega                     2
# Café                              2
# Chinese Restaurant                2
# American Restaurant               2
# Noodle House                      2
# Cheese Shop                       2
# Performing Arts Venue             2
# Japanese Restaurant               2
# Lounge                            1
# Snack Place                       1
# Park                              1
# Herbs & Spices Store              1
# Fish Market                       1
# Gym                               1
# Supermarket                       1
# French Restaurant                 1
# Vegetarian / Vegan Restaurant     1
# Theater                           1
# Bar                               1
# Social Club                       1
# Gourmet Shop                      1
# Market                            1
# Dessert Shop                      1
# Chocolate Shop                    1
# Breakfast Spot                    1
# Stadium                           1
# Sake Bar                          1
# Pizza Place                       1
# Other Nightlife                   1
# Art Museum                        1
# Bubble Tea Shop                   1
# Steakhouse                        1
# Stationery Store                  1
# New American Restaurant           1
# Women's Store                     1
# Yoga Studio                       1
# Building                          1
# Concert Hall                      1
# Financial or Legal Service        1
# Frozen Yogurt Shop                1
# Theme Park Ride / Attraction      1
# Spanish Restaurant                1
# Wine Shop                         1
# Cocktail Bar                      1
# Mini Golf                         1
# Plaza                             1
# Thai Restaurant                   1
# Waterfront                        1
# Bookstore                         1
# Name: categories, dtype: int64

# %% [markdown]
# **Function for extracting venues for all the regions:**

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):

        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            limit)

        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['District', 
                  'District Latitude', 
                  'District Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']

    return(nearby_venues)

# %%
venues_washington = getNearbyVenues(names=df_districts['Region'],
                                   latitudes=df_districts['Latitude'],
                                   longitudes=df_districts['Longitude']
                                  )

# %%
venues_washington.sample(10)
# Out:
#         District  District Latitude  District Longitude  \
# 354       Renton          47.479908         -122.203450
# 292       Auburn          47.307537         -122.230181
# 270       Duvall          47.742322         -121.985678
# 473  Woodinville          47.754583         -122.158890
# 48       Seattle          47.603832         -122.330062
# 340     Issaquah          47.534878         -122.043297
# 168      Redmond          47.669414         -122.123877
# 455   North Bend          47.495946         -121.785154
# 565      Bothell          47.759870         -122.206829
# 159      Redmond          47.669414         -122.123877
#
#                            Venue  Venue Latitude  Venue Longitude  \
# 354            Uptown Glassworks       47.480057      -122.203965
# 292                      Sushido       47.307719      -122.228011
# 270       The Duvall Coffeehouse       47.741218      -121.985982
# 473                    Mi Tierra       47.754946      -122.160623
# 48                      Altstadt       47.600480      -122.334399
# 340  Issaquah Garage Door Repair       47.531768      -122.042522
# 168             Prime Steakhouse       47.673347      -122.122127
# 455                       Redbox       47.493370      -121.780624
# 565      Countryside Donut House       47.760398      -122.206314
# 159                  Chick'n Fix       47.672675      -122.122648
#
#          Venue Category
# 354         Art Gallery
# 292    Sushi Restaurant
# 270         Coffee Shop
# 473  Mexican Restaurant
# 48    German Restaurant
# 340   Other Repair Shop
# 168          Steakhouse
# 455         Video Store
# 565          Donut Shop
# 159          Food Truck

# %%
venues_washington.groupby('District').count()[['Venue']].sort_values(by='Venue', ascending=False)
# Out:
#                Venue
# District
# Seattle          100
# Bellevue          70
# Redmond           70
# Renton            48
# Woodinville       45
# Bothell           41
# Vashon            37
# North Bend        28
# Auburn            27
# Duvall            23
# Kenmore           21
# Snoqualmie        20
# Kent              17
# Fall City         15
# Carnation         14
# Enumclaw          12
# Black Diamond      7
# Medina             5
# Kirkland           5
# Maple Valley       4
# Mercer Island      4
# Issaquah           3
# Federal Way        2
# Sammamish          1

# %%
venues_washington.rename(columns={'District':'Region'}, inplace=True)

# %%
venues_washington.to_csv('venues_washington.csv')
